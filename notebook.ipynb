# %% [markdown]
# # High-speed-rail document analysis
#
# By [Ben Welsh](https://palewire/who-is-ben-welsh/)
#
# This analysis was conducted for April 27, 2019 story ["How California’s faltering high-speed rail project was ‘captured’ by costly consultants."](https://www.latimes.com/local/california/la-me-california-high-speed-rail-consultants-20190426-story.html)
#
# It found that outside consultants have provided more than 3,000 environmental statements, business documents and other reports to the California High-Speed Rail Authority. Altogether they contain more than 152,000 pages.

# %% [markdown]
# ## How we did it

# %% [markdown]
# Import Python tools

# %%
import os
import PyPDF2
import pathlib
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlretrieve

# %% [markdown]
# Set output directory where documents will be saved.

# %%
output_dir = pathlib.Path(os.getenv("OUTPUT_DIR") or "./output")

# %% [markdown]
# Read in a list of all the URLs on the rail authority's site that contain consultant reports.

# %%
page_list = open("./input/urls.csv").read().split("\n")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# notebook.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/notebook.ipynb?repo%3Dmconsulting%2Fhsr-document-analysis#X10scmVwbw%3D%3D?line=0'>1</a> page_list = open("./input/urls.csv").read().split("\n")
#
# FileNotFoundError: [Errno 2] No such file or directory: './input/urls.csv'

# %% [markdown]
# Request each page and parse out all of its PDF links

# %%
url='https://www.sbafla.com/fsb/PerformanceReports/AlternativeAssetStatusPerformanceReport.aspx'

r = requests.get(url)
soup = BeautifulSoup(r.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head id="Head">
# <!--*********************************************-->
# <!-- DNN Platform - http://www.dnnsoftware.com   -->
# <!-- Copyright (c) 2002-2015, by DNN Corporation -->
# <!--*********************************************-->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>
# 	Alternative Asset Status &amp; Performance Report
# </title><meta content="Alternative Asset Status &amp; Performance Report" id="MetaDescription" name="DESCRIPTION"/><meta content="Alternative,Asset,Status,Performance,Report,DotNetNuke,DNN" id="MetaKeywords" name="KEYWORDS"/><meta content="DotNetNuke " id="MetaGenerator" name="GENERATOR"/><meta content="INDEX, FOLLOW" id="MetaRobots" name="ROBOTS"/><link href="/fsb/Resources/Shared/stylesheets/dnndefault/7.0.0/default.css?cdv=223" rel="stylesheet" type="text/css"/><link href="/fsb/DesktopModules/Links/module.css?cdv=223" rel="stylesheet" type="text/css"/><link href="/fsb/Resources/Search/SearchSkinObjectPreview.css?cdv=223" rel="stylesheet" type="text/css"/><link href="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/skin.css?cdv=223" rel="stylesheet" type="text/css"/><link href="/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/container.css?cdv=223" rel="stylesheet" type="text/css"/><link href="/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/Container05.css?cdv=223" rel="stylesheet" type="text/css"/><link href="/fsb/Portals/FSB/portal.css?cdv=223" rel="stylesheet" type="text/css"/><script src="/fsb/Resources/libraries/jQuery/01_09_01/jquery.js?cdv=223" type="text/javascript"></script><!--[if IE 8]><link id="IE8Minus" rel="stylesheet" type="text/css" href="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/css/ie8style.css" /><![endif]--><script type="text/javascript">
# //<![CDATA[
#     var analytics_page_startTime = (new Date()).getTime();
# //]]>
# </script>
# <script type="text/javascript">
# 			      var _gaq = _gaq || [];
# 			      _gaq.push(['_setAccount', 'UA-34141032-1']);
# 			      _gaq.push(['_trackPageview']);
#
# 			      (function() {
# 				    var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 				    ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 				    var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 			      })();
# 			    </script>
# <meta content="width=device-width, minimum-scale=1.0, maximum-scale=2.0" name="viewport"/>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="96P3Y-G5FBX-JNYCB-BG8J3-7E55W",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"96P3Y-G5FBX-JNYCB-BG8J3-7E55W";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="qiwtgnyx33yswy7ggqea-f-154e6770f-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"34","ak.cp":"1100731","ak.ai":parseInt("656320",10),"ak.ol":"0","ak.cr":47,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"4092dcbc","ak.r":39396,"ak.a2":n,"ak.m":"dsca","ak.n":"essl","ak.bpcip":"130.45.51.0","ak.cport":59189,"ak.gh":"23.47.59.43","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1676030984","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"23","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
# <body id="Body">
# <form action="/fsb/PerformanceReports/AlternativeAssetStatusPerformanceReport.aspx" enctype="multipart/form-data" id="Form" method="post">
# <div class="aspNetHidden">
# <input id="StylesheetManager_TSSM" name="StylesheetManager_TSSM" type="hidden" value=""/>
# <input id="ScriptManager_TSM" name="ScriptManager_TSM" type="hidden" value=""/>
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# </div>
# <script src="/fsb/DesktopModules/Links/js/toggle.js" type="text/javascript"></script>
# <script src="/fsb/Telerik.Web.UI.WebResource.axd?_TSM_HiddenField_=ScriptManager_TSM&amp;compress=1&amp;_TSM_CombinedScripts_=%3b%3bSystem.Web.Extensions%2c+Version%3d4.0.0.0%2c+Culture%3dneutral%2c+PublicKeyToken%3d31bf3856ad364e35%3aen-US%3a9ddf364d-d65d-4f01-a69e-8b015049e026%3aea597d4b%3ab25378d2" type="text/javascript"></script>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="EC52FD85"/>
# <input id="__VIEWSTATEENCRYPTED" name="__VIEWSTATEENCRYPTED" type="hidden" value=""/>
# <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="ZMsAKVwhS07Hl18oZfdK/ppwMZTgxxQ+68gHwnE5+kYOTksoY/eaZVEJObzsW7y0gU2cGKO3WBXEtQaX9CnEXQp9CazHmqMvKezbbIe0gZqZUW2FbpqLuEUuu5huJDcH2I47CSxL3je2wt15xQuUO0TAQ5uCYjnuwwVKWNqxDTli47YVAY1pjC28Qqd/F/D+IqztxA=="/>
# </div><script src="/fsb/js/dnn.js?cdv=223" type="text/javascript"></script><script src="/fsb/js/dnncore.js?cdv=223" type="text/javascript"></script><script src="/fsb/Resources/Search/SearchSkinObjectPreview.js?cdv=223" type="text/javascript"></script><script src="/fsb/DesktopModules/DNNCorp/EvoqContentLibrary/ClientScripts/dnn.analytics.Injected.js?cdv=223" type="text/javascript"></script><script src="/fsb/js/dnn.servicesframework.js?cdv=223" type="text/javascript"></script><script type="text/javascript">
# //<![CDATA[
# Sys.WebForms.PageRequestManager._initialize('ScriptManager', 'Form', [], [], [], 90, '');
# //]]>
# </script>
# <!--[if lt IE 9]>
# <script src="https://html5shim.googlecode.com/svn/trunk/html5.js"></script>
# <![endif]-->
# <div id="ControlPanelWrapper">
# </div>
# <div class="cleanweb" id="skin_wrap">
# <div class="skin_top_line"></div>
# <!--start skin header-->
# <header id="skin_header">
# <div class="skin_width clearafter">
# <div class="icons_bar">
# <!--start top icons-->
# <div class="icons_menu">
# <div class="language_style"> <a class="language-button lang-tipsy" title="Change Language"><span></span></a>
# <div id="Language">
# <div class="language-object">
# </div>
# </div>
# </div>
# <div class="login_style">
# <div class="login-button user-tipsy" title="Click to Login"><span>
# <a class="User" href="https://www.sbafla.com/fsb/LoginS/tabid/707/Default.aspx?returnurl=%2ffsb%2fPerformanceReports%2fAlternativeAssetStatusPerformanceReport.aspx" id="dnn_dnnLOGIN3_loginLink" onclick="this.disabled=true;" rel="nofollow" title="Login">Login</a>
# </span></div>
# <div class="user_login">
# <a class="User" href="https://www.sbafla.com/fsb/LoginS/tabid/707/Default.aspx?returnurl=%2ffsb%2fPerformanceReports%2fAlternativeAssetStatusPerformanceReport.aspx" id="dnn_dnnLOGIN_loginLink" onclick="this.disabled=true;" rel="nofollow" title="Login">Login</a>
# </div>
# </div>
# <div class="user_style">
# <a class="user-button user-tipsy" title="Click to Register"><span></span></a>
# <div class="user_register">
# </div>
# </div>
# <div class="search_style"> <a class="search-button search-tipsy" title="Click to Search"><span></span></a> <a class="search-button-close search-tipsy" title="Close Search"><span></span></a>
# <div id="Search">
# <div class="search_position">
# <span id="dnn_dnnSEARCH_ClassicSearch">
# <span class="searchInputContainer" data-moreresults="See More Results" data-noresult="No Results Found">
# <input autocomplete="off" class="NormalTextBox" id="dnn_dnnSEARCH_txtSearch" maxlength="255" name="dnn$dnnSEARCH$txtSearch" placeholder="Search..." size="20" type="text"/>
# <a class="dnnSearchBoxClearText" title="Clear search text"></a>
# </span>
# <a class="searchcss" href="javascript:__doPostBack('dnn$dnnSEARCH$cmdSearch','')" id="dnn_dnnSEARCH_cmdSearch">Search</a>
# </span>
# <script type="text/javascript">
#     $(function() {
#         if (typeof dnn != "undefined" && typeof dnn.searchSkinObject != "undefined") {
#             var searchSkinObject = new dnn.searchSkinObject({
#                 delayTriggerAutoSearch : 400,
#                 minCharRequiredTriggerAutoSearch : 2,
#                 searchType: 'S',
#                 enableWildSearch: true,
#                 cultureCode: 'en-US',
#                 portalId: -1
#                 }
#             );
#             searchSkinObject.init();
#
#
#             // attach classic search
#             var siteBtn = $('#dnn_dnnSEARCH_SiteRadioButton');
#             var webBtn = $('#dnn_dnnSEARCH_WebRadioButton');
#             var clickHandler = function() {
#                 if (siteBtn.is(':checked')) searchSkinObject.settings.searchType = 'S';
#                 else searchSkinObject.settings.searchType = 'W';
#             };
#             siteBtn.on('change', clickHandler);
#             webBtn.on('change', clickHandler);
#
#
#         }
#     });
# </script>
# </div>
# </div>
# </div>
# </div>
# <!--end top icons-->
# </div>
# <div class="clear"></div>
# <div class="header_top clearafter">
# <!--start logo-->
# <div class="logo_style">
# <a href="https://www.sbafla.com/fsb/Home.aspx" id="dnn_dnnLOGO_hypLogo" title="State Board of Administration - Internet"><img alt="State Board of Administration - Internet" id="dnn_dnnLOGO_imgLogo" src="/fsb/Portals/FSB/Images/LogoExt.png?ver=2016-07-08-114148-183"/></a>
# </div>
# <!--end logo-->
# <!--start mobile top icons-->
# <div class="mobile_UI">
# <div class="mobile_menu"><a href="javascript:animatedcollapse.toggle('nav_box')" title="Menu"><img alt="" src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/images/blank.gif"/></a></div>
# <div class="mobile_language"><a href="javascript:animatedcollapse.toggle('Language2')" title="Change Language"><img alt="" src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/images/blank.gif"/></a></div>
# <div class="mobile_login">
# <a class="mobile_login_button" href="javascript:animatedcollapse.toggle('Login2')" title="Click to Login"><img alt="" src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/images/blank.gif"/></a>
# </div>
# <div class="mobile_user">
# <a class="mobile_register" href="javascript:animatedcollapse.toggle('User2')" title="Click to Register"><img alt="" src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/images/blank.gif"/></a>
# </div>
# <div class="mobile_search"><a href="javascript:animatedcollapse.toggle('Search2')" title="Click to Search"><img alt="" src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/images/blank.gif"/></a></div>
# </div>
# <!--end mobile top icons-->
# <!--start nav-->
# <nav id="skin_nav">
# <div id="nav_box">
# <div id="megaMenu">
# <ul class="root">
# <li class="item first child-1"><a href="https://www.sbafla.com/fsb/Home.aspx" target=""><span>Home</span></a></li>
# <li class="item breadcrumb haschild child-2"><a href="https://www.sbafla.com/fsb/PerformanceReports.aspx" target=""><span>Performance &amp; Reports<i class="navarrow"></i></span></a><div class="category">
# <ul>
# <li class="item first child-1"><a href="https://www.sbafla.com/fsb/PerformanceReports/MonthlyReportstoTrustees/2022Reports.aspx" target=""><span>Monthly Reports to Trustees</span></a></li>
# <li class="item child-2"><a href="https://www.sbafla.com/fsb/PerformanceReports/AnnualInvestmentReports.aspx" target=""><span>Annual Investment Reports</span></a></li>
# <li class="item child-3"><a href="https://www.sbafla.com/fsb/PerformanceReports/AnnualDebtServiceReports.aspx" target=""><span>Annual Debt Service Reports</span></a></li>
# <li class="item child-4"><a href="https://www.sbafla.com/fsb/PerformanceReports/NewManagersReports.aspx" target=""><span>New Managers Reports</span></a></li>
# <li class="item selected last breadcrumb child-5"><a href="https://www.sbafla.com/fsb/PerformanceReports/AlternativeAssetStatusPerformanceReport.aspx" target=""><span>Alternative Asset Status Performance Report</span></a></li>
# </ul>
# </div>
# </li>
# <li class="item haschild child-3"><a href="https://www.sbafla.com/fsb/Trustees,CouncilsCommittees.aspx" target=""><span>Trustees, Councils &amp; Committees<i class="navarrow"></i></span></a><div class="category">
# <ul>
# <li class="item first haschild child-1"><a href="https://www.sbafla.com/fsb/Trustees,CouncilsCommittees/Trustees.aspx" target=""><span>Trustees</span></a><div class="leaf">
# <ul>
# <li class="item first last child-1"><a href="https://www.sbafla.com/fsb/Trustees,CouncilsCommittees/Trustees/2023TrusteeMeetingItems.aspx" target=""><span>2023 Trustee Meeting Items</span></a></li>
# </ul>
# </div>
# </li>
# <li class="item haschild child-2"><a href="https://www.sbafla.com/fsb/Trustees,CouncilsCommittees/InvestmentAdvisoryCouncil.aspx" target=""><span>Investment Advisory Council</span></a><div class="leaf">
# <ul>
# <li class="item first last child-1"><a href="https://www.sbafla.com/fsb/Trustees,CouncilsCommittees/InvestmentAdvisoryCouncil/2023IACMeetingItems.aspx" target=""><span>2023 IAC Meeting Items</span></a></li>
# </ul>
# </div>
# </li>
# <li class="item haschild child-3"><a href="https://www.sbafla.com/fsb/Trustees,CouncilsCommittees/AuditCommittee.aspx" target=""><span>Audit Committee</span></a><div class="leaf">
# <ul>
# <li class="item first last child-1"><a href="https://www.sbafla.com/fsb/Trustees,CouncilsCommittees/AuditCommittee/2023ACMeetingItems.aspx" target=""><span>2023 AC Meeting Items</span></a></li>
# </ul>
# </div>
# </li>
# <li class="item child-4"><a href="https://fhcf.sbafla.com/advisory-council-home/" target="_blank"><span>FHCF Advisory Council</span></a></li>
# <li class="item last child-5"><a href="http://fchlpm.sbafla.com/" target="_blank"><span>Commission on Hurricane Loss</span></a></li>
# </ul>
# </div>
# </li>
# <li class="item haschild child-4"><a href="https://www.sbafla.com/fsb/FundsWeManage.aspx" target=""><span>Funds We Manage<i class="navarrow"></i></span></a><div class="category">
# <ul>
# <li class="item first haschild child-1"><a href="https://www.sbafla.com/fsb/FundsWeManage/FRSPensionPlan.aspx" target=""><span>FRS Pension Plan</span></a><div class="leaf">
# <ul>
# <li class="item first child-1"><a href="https://www.sbafla.com/fsb/FundsWeManage/FRSPensionPlan/FloridaGrowthFund.aspx" target=""><span>Florida Growth Fund</span></a></li>
# <li class="item last haschild child-2"><a href="https://www.sbafla.com/fsb/FundsWeManage/FRSPensionPlan/GlobalGovernanceMandates.aspx" target=""><span>Global Governance Mandates</span></a><div class="leaf">
# <ul>
# <li class="item first last child-1"><a href="https://www.sbafla.com/fsb/FundsWeManage/FRSPensionPlan/GlobalGovernanceMandates/QuarterlyReports.aspx" target=""><span>Quarterly Reports</span></a></li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# </li>
# <li class="item haschild child-2"><a href="https://www.sbafla.com/fsb/FundsWeManage/FRSInvestmentPlan.aspx" target=""><span>FRS Investment Plan</span></a><div class="leaf">
# <ul>
# <li class="item first last child-1"><a href="http://www.myfrs.com" target="_blank"><span>MyFRS</span></a></li>
# </ul>
# </div>
# </li>
# <li class="item child-3"><a href="https://www.sbafla.com/prime/" target="_blank"><span>Florida PRIME</span></a></li>
# <li class="item last child-4"><a href="http://www.sbafla.com/fhcf/" target="_blank"><span>Florida Hurricane Cat Fund</span></a></li>
# </ul>
# </div>
# </li>
# <li class="item haschild child-5"><a href="https://www.sbafla.com/fsb/Governance.aspx" target=""><span>Governance<i class="navarrow"></i></span></a><div class="category">
# <ul>
# <li class="item first child-1"><a href="/fsb/LinkClick.aspx?fileticket=iiaxxkgg4ww%3d&amp;tabid=838&amp;portalid=11" target="_blank"><span>Annual Corporate Governance Summary</span></a></li>
# <li class="item child-2"><a href="/fsb/LinkClick.aspx?fileticket=SvFaBpJJJSM%3d&amp;tabid=839&amp;portalid=11" target="_blank"><span>Principles &amp; Proxy Voting Guidelines</span></a></li>
# <li class="item child-3"><a href="https://viewpoint.glasslewis.com/WD/?siteId=FSBA" target="_blank"><span>Voting Disclosure</span></a></li>
# <li class="item child-4"><a href="https://www.sbafla.com/fsb/FundsWeManage/FRSPensionPlan/GlobalGovernanceMandates.aspx" target=""><span>Global Governance Mandates</span></a></li>
# <li class="item last child-5"><a href="https://public.tableau.com/views/ProxyVotingDataAnalytics-forTableauPublic/Overview1?:showVizHome=no&amp;:embed=true&amp;:display_count=yes" target="_blank"><span>Historical Proxy Voting</span></a></li>
# </ul>
# </div>
# </li>
# <li class="item haschild child-6"><a href="https://www.sbafla.com/fsb/DoingBusinesswiththeSBA/Vendors.aspx" target=""><span>Doing Business with the SBA<i class="navarrow"></i></span></a><div class="category">
# <ul>
# <li class="item first child-1"><a href="https://www.sbafla.com/fsb/DoingBusinesswiththeSBA/Vendors.aspx" target=""><span>Vendors</span></a></li>
# <li class="item child-2"><a href="https://www.sbafla.com/fsb/DoingBusinesswiththeSBA/InvestmentManagementServices.aspx" target=""><span>Investment Management Services</span></a></li>
# <li class="item last child-3"><a href="https://www.sbafla.com/fsb/DoingBusinesswiththeSBA/TradingCounterpartyServices.aspx" target=""><span>Trading Counterparty Services</span></a></li>
# </ul>
# </div>
# </li>
# <li class="item haschild child-7"><a href="https://www.sbafla.com/fsb/SBAOrgChart.aspx" target=""><span>Administration<i class="navarrow"></i></span></a><div class="category">
# <ul>
# <li class="item first child-1"><a href="https://www.sbafla.com/budget/default.aspx" target="_blank"><span>Operating Budget</span></a></li>
# <li class="item child-2"><a href="https://www.sbafla.com/fsb/SBAOrgChart.aspx" target=""><span>SBA Organizational Chart</span></a></li>
# <li class="item last child-3"><a href="https://www.sbafla.com/travel/" target="_blank"><span>Travel Data</span></a></li>
# </ul>
# </div>
# </li>
# <li class="item haschild child-8"><a href="https://www.sbafla.com/fsb/Employment.aspx" target=""><span>Employment<i class="navarrow"></i></span></a><div class="category">
# <ul>
# <li class="item first child-1"><a href="https://www.sbafla.com/fsb/Employment/EmploymentGuidelines.aspx" target=""><span>Employment Guidelines</span></a></li>
# <li class="item child-2"><a href="https://jobs.sbafla.com/psc/SBA/EMPLOYEE/HRMS/c/HRS_HRAM_FL.HRS_CG_SEARCH_FL.GBL?FOCUS=Applicant" target="_blank"><span>Browse Job Openings</span></a></li>
# <li class="item child-3"><a href="https://www.sbafla.com/fsb/Employment/SBABenefits.aspx" target=""><span>SBA Benefits</span></a></li>
# <li class="item child-4"><a href="https://www.sbafla.com/fsb/Employment/CollegeInternshipProgram.aspx" target=""><span>College Internship Program</span></a></li>
# <li class="item last child-5"><a href="https://www.sbafla.com/fsb/Employment/LivinginTallahassee.aspx" target=""><span>Living in Tallahassee</span></a></li>
# </ul>
# </div>
# </li>
# <li class="item haschild child-9"><a href="https://www.sbafla.com/fsb/Newsroom/2021NewsReleases.aspx" target=""><span>Newsroom<i class="navarrow"></i></span></a><div class="category">
# <ul>
# <li class="item first child-1"><a href="https://www.sbafla.com/fsb/Newsroom/2021NewsReleases.aspx" target=""><span>Topics At A Glance</span></a></li>
# <li class="item last child-2"><a href="https://www.sbafla.com/fsb/Newsroom/2021NewsReleases.aspx" target=""><span>Yearly News Releases</span></a></li>
# </ul>
# </div>
# </li>
# <li class="item last child-10"><a href="https://www.sbafla.com/fsb/ContactUs.aspx" target=""><span>Contact Us</span></a></li>
# </ul>
# </div>
# </div>
# </nav>
# <!--end nav-->
# <div id="Language2">
# <div class="mobile_language_style">
# <div class="language-object">
# </div>
# </div>
# </div>
# <div id="Login2">
# <a class="User" href="https://www.sbafla.com/fsb/LoginS/tabid/707/Default.aspx?returnurl=%2ffsb%2fPerformanceReports%2fAlternativeAssetStatusPerformanceReport.aspx" id="dnn_dnnLOGIN2_loginLink" onclick="this.disabled=true;" rel="nofollow" title="Login">Login</a>
# </div>
# <div id="User2">
# </div>
# <div class="clearafter" id="Mobile_Profile">
# <div class="mobile_profile_style">
# </div>
# </div>
# <div id="Search2">
# <div class="search_position">
# <span id="dnn_dnnSEARCH2_ClassicSearch">
# <span class="searchInputContainer" data-moreresults="See More Results" data-noresult="No Results Found">
# <input autocomplete="off" class="NormalTextBox" id="dnn_dnnSEARCH2_txtSearch" maxlength="255" name="dnn$dnnSEARCH2$txtSearch" placeholder="Search..." size="20" type="text"/>
# <a class="dnnSearchBoxClearText" title="Clear search text"></a>
# </span>
# <a class="searchcss" href="javascript:__doPostBack('dnn$dnnSEARCH2$cmdSearch','')" id="dnn_dnnSEARCH2_cmdSearch">Search</a>
# </span>
# <script type="text/javascript">
#     $(function() {
#         if (typeof dnn != "undefined" && typeof dnn.searchSkinObject != "undefined") {
#             var searchSkinObject = new dnn.searchSkinObject({
#                 delayTriggerAutoSearch : 400,
#                 minCharRequiredTriggerAutoSearch : 2,
#                 searchType: 'S',
#                 enableWildSearch: true,
#                 cultureCode: 'en-US',
#                 portalId: -1
#                 }
#             );
#             searchSkinObject.init();
#
#
#             // attach classic search
#             var siteBtn = $('#dnn_dnnSEARCH2_SiteRadioButton');
#             var webBtn = $('#dnn_dnnSEARCH2_WebRadioButton');
#             var clickHandler = function() {
#                 if (siteBtn.is(':checked')) searchSkinObject.settings.searchType = 'S';
#                 else searchSkinObject.settings.searchType = 'W';
#             };
#             siteBtn.on('change', clickHandler);
#             webBtn.on('change', clickHandler);
#
#
#         }
#     });
# </script>
# </div>
# </div>
# </div>
# </div>
# </header>
# <!--end skin header-->
# <!--start skin banner-->
# <div class="skin_banner">
# <div class="banner_shadow"></div>
# <div class="banner_style">
# <div class="bannerpane DNNEmptyPane" id="dnn_BannerPane"></div>
# </div>
# </div>
# <!--end skin banner-->
# <div class="breadcrumb_bar skin_width">
# <div class="breadcrumb_style">
# <span class="Breadcrumb_text" id="dnn_dnnTEXT_lblText"></span>
# <span id="dnn_dnnBREADCRUMB_lblBreadCrumb" itemprop="breadcrumb" itemscope="" itemtype="https://schema.org/breadcrumb"><span itemscope="" itemtype="http://schema.org/BreadcrumbList"><span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a class="Breadcrumb" href="https://www.sbafla.com/fsb/PerformanceReports.aspx" itemprop="item"><span itemprop="name">Performance &amp; Reports</span></a><meta content="1" itemprop="position"/></span>  &gt;&gt;  <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a class="Breadcrumb" href="https://www.sbafla.com/fsb/PerformanceReports/AlternativeAssetStatusPerformanceReport.aspx" itemprop="item"><span itemprop="name">Alternative Asset Status Performance Report</span></a><meta content="2" itemprop="position"/></span></span></span>
# </div>
# </div>
# <div class="skin_width">
# <!--start main content area-->
# <section class="skin_content">
# <div class="row-fluid dnnpane">
# <div class="content_grid12 span12" id="dnn_ContentPane"><div class="DnnModule DnnModule-DNN_Links DnnModule-5058"><a name="5058"></a>
# <div class="LimeGreen05_style">
# <div class="LimeGreen05_top_bg">
# <div class="c_icon LimeGreen05_top_height">
# </div>
# <div class="c_title LimeGreen05_top_height">
# <h2 class="c_titles"><span class="c_title_white" id="dnn_ctr5058_dnnTITLE_titleLabel">2022 Alternative Asset Status &amp; Performance Report</span>
# </h2>
# </div>
# <div class="LimeGreen05_c_menu">
# </div>
# <div class="LimeGreen05_c_help">
# </div>
# <div class="clear_float"></div>
# </div>
# <div class="c_content_style">
# <div class="LimeGreen05_content" id="dnn_ctr5058_ContentPane"><!-- Start_Module_5058 --><div class="DNNModuleContent ModDNNLinksC" id="dnn_ctr5058_ModuleContent">
# <div class="link_module" id="dnn_ctr5058_Links_pnlList">
# <ul class="linklist">
# <li class="linkitem" style="white-space: nowrap">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=uazuwH5kAsI%3d&amp;tabid=851&amp;portalid=11&amp;mid=5058" id="dnn_ctr5058_Links_lstLinks_linkHyp_0" target="_blank">
#                     Q2 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr5058_Links_lstLinks_pnlDescription_0" style="display: none">
# <span class="Normal" id="dnn_ctr5058_Links_lstLinks_lbldescrdiv_0"></span>
# </div>
# </li>
# <li class="linkitem" style="white-space: nowrap">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=ztOKnuTfTo8%3d&amp;tabid=851&amp;portalid=11&amp;mid=5058" id="dnn_ctr5058_Links_lstLinks_linkHyp_1" target="_blank">
#                     Q1 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr5058_Links_lstLinks_pnlDescription_1" style="display: none">
# <span class="Normal" id="dnn_ctr5058_Links_lstLinks_lbldescrdiv_1"></span>
# </div>
# </li>
# <div style="clear: both;"></div>
# </ul>
# </div>
# </div><!-- End_Module_5058 --></div>
# </div>
# <div class="c_footer">
# <div class="c_footer_l">
# </div>
# <div class="c_footer_r">
# </div>
# <div class="clear_float"></div>
# </div>
# </div>
# <div class="LimeGreen05_footer"></div></div><div class="DnnModule DnnModule-DNN_Links DnnModule-4014"><a name="4014"></a>
# <div class="LimeGreen05_style">
# <div class="LimeGreen05_top_bg">
# <div class="c_icon LimeGreen05_top_height">
# </div>
# <div class="c_title LimeGreen05_top_height">
# <h2 class="c_titles"><span class="c_title_white" id="dnn_ctr4014_dnnTITLE_titleLabel">2021 Alternative Asset Status &amp; Performance Report</span>
# </h2>
# </div>
# <div class="LimeGreen05_c_menu">
# </div>
# <div class="LimeGreen05_c_help">
# </div>
# <div class="clear_float"></div>
# </div>
# <div class="c_content_style">
# <div class="LimeGreen05_content" id="dnn_ctr4014_ContentPane"><!-- Start_Module_4014 --><div class="DNNModuleContent ModDNNLinksC" id="dnn_ctr4014_ModuleContent">
# <div class="link_module" id="dnn_ctr4014_Links_pnlList">
# <ul class="linklist">
# <li class="linkitem" style="white-space: nowrap">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=M5orfIRljc8%3d&amp;tabid=851&amp;portalid=11&amp;mid=4014" id="dnn_ctr4014_Links_lstLinks_linkHyp_0" target="_blank">
#                     Q4 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr4014_Links_lstLinks_pnlDescription_0" style="display: none">
# <span class="Normal" id="dnn_ctr4014_Links_lstLinks_lbldescrdiv_0"></span>
# </div>
# </li>
# <li class="linkitem" style="white-space: nowrap">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=GM9gZMADzj4%3d&amp;tabid=851&amp;portalid=11&amp;mid=4014" id="dnn_ctr4014_Links_lstLinks_linkHyp_1" target="_blank">
#                     Q3 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr4014_Links_lstLinks_pnlDescription_1" style="display: none">
# <span class="Normal" id="dnn_ctr4014_Links_lstLinks_lbldescrdiv_1"></span>
# </div>
# </li>
# <li class="linkitem" style="white-space: nowrap">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=68C569aFHbc%3d&amp;tabid=851&amp;portalid=11&amp;mid=4014" id="dnn_ctr4014_Links_lstLinks_linkHyp_2" target="_blank">
#                     Q2 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr4014_Links_lstLinks_pnlDescription_2" style="display: none">
# <span class="Normal" id="dnn_ctr4014_Links_lstLinks_lbldescrdiv_2"></span>
# </div>
# </li>
# <li class="linkitem" style="white-space: nowrap">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=wH6kPqMTp3w%3d&amp;tabid=851&amp;portalid=11&amp;mid=4014" id="dnn_ctr4014_Links_lstLinks_linkHyp_3" target="_blank">
#                     Q1 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr4014_Links_lstLinks_pnlDescription_3" style="display: none">
# <span class="Normal" id="dnn_ctr4014_Links_lstLinks_lbldescrdiv_3"></span>
# </div>
# </li>
# <div style="clear: both;"></div>
# </ul>
# </div>
# </div><!-- End_Module_4014 --></div>
# </div>
# <div class="c_footer">
# <div class="c_footer_l">
# </div>
# <div class="c_footer_r">
# </div>
# <div class="clear_float"></div>
# </div>
# </div>
# <div class="LimeGreen05_footer"></div></div><div class="DnnModule DnnModule-DNN_Links DnnModule-3935"><a name="3935"></a>
# <div class="LimeGreen05_style">
# <div class="LimeGreen05_top_bg">
# <div class="c_icon LimeGreen05_top_height">
# </div>
# <div class="c_title LimeGreen05_top_height">
# <h2 class="c_titles"><span class="c_title_white" id="dnn_ctr3935_dnnTITLE_titleLabel">2020 Alternative Asset Status &amp; Performance Report</span>
# </h2>
# </div>
# <div class="LimeGreen05_c_menu">
# </div>
# <div class="LimeGreen05_c_help">
# </div>
# <div class="clear_float"></div>
# </div>
# <div class="c_content_style">
# <div class="LimeGreen05_content" id="dnn_ctr3935_ContentPane"><!-- Start_Module_3935 --><div class="DNNModuleContent ModDNNLinksC" id="dnn_ctr3935_ModuleContent">
# <div class="link_module" id="dnn_ctr3935_Links_pnlList">
# <ul class="linklist">
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=NHi-NjSpFzA%3d&amp;tabid=851&amp;portalid=11&amp;mid=3935" id="dnn_ctr3935_Links_lstLinks_linkHyp_0" target="_blank">
#                     Q4 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3935_Links_lstLinks_pnlDescription_0" style="display: none">
# <span class="Normal" id="dnn_ctr3935_Links_lstLinks_lbldescrdiv_0"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=3V7Nb910RHM%3d&amp;tabid=851&amp;portalid=11&amp;mid=3935" id="dnn_ctr3935_Links_lstLinks_linkHyp_1" target="_blank">
#                     Q3 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3935_Links_lstLinks_pnlDescription_1" style="display: none">
# <span class="Normal" id="dnn_ctr3935_Links_lstLinks_lbldescrdiv_1"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=Vyua1Pengx0%3d&amp;tabid=851&amp;portalid=11&amp;mid=3935" id="dnn_ctr3935_Links_lstLinks_linkHyp_2" target="_blank">
#                     Q2 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3935_Links_lstLinks_pnlDescription_2" style="display: none">
# <span class="Normal" id="dnn_ctr3935_Links_lstLinks_lbldescrdiv_2"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=Q6sKTQPEImM%3d&amp;tabid=851&amp;portalid=11&amp;mid=3935" id="dnn_ctr3935_Links_lstLinks_linkHyp_3" target="_blank">
#                     Q1 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3935_Links_lstLinks_pnlDescription_3" style="display: none">
# <span class="Normal" id="dnn_ctr3935_Links_lstLinks_lbldescrdiv_3"></span>
# </div>
# </li>
# <div style="clear: both;"></div>
# </ul>
# </div>
# </div><!-- End_Module_3935 --></div>
# </div>
# <div class="c_footer">
# <div class="c_footer_l">
# </div>
# <div class="c_footer_r">
# </div>
# <div class="clear_float"></div>
# </div>
# </div>
# <div class="LimeGreen05_footer"></div></div><div class="DnnModule DnnModule-DNN_Links DnnModule-3867"><a name="3867"></a>
# <div class="LimeGreen05_style">
# <div class="LimeGreen05_top_bg">
# <div class="c_icon LimeGreen05_top_height">
# </div>
# <div class="c_title LimeGreen05_top_height">
# <h2 class="c_titles"><span class="c_title_white" id="dnn_ctr3867_dnnTITLE_titleLabel">2019 Alternative Asset Status &amp; Performance Report</span>
# </h2>
# </div>
# <div class="LimeGreen05_c_menu">
# </div>
# <div class="LimeGreen05_c_help">
# </div>
# <div class="clear_float"></div>
# </div>
# <div class="c_content_style">
# <div class="LimeGreen05_content" id="dnn_ctr3867_ContentPane"><!-- Start_Module_3867 --><div class="DNNModuleContent ModDNNLinksC" id="dnn_ctr3867_ModuleContent">
# <div class="link_module" id="dnn_ctr3867_Links_pnlList">
# <ul class="linklist">
# <li class="linkitem" style="white-space: nowrap">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=Uc0AUuKg2dU%3d&amp;tabid=851&amp;portalid=11&amp;mid=3867" id="dnn_ctr3867_Links_lstLinks_linkHyp_0" target="_blank">
#                     Q4 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3867_Links_lstLinks_pnlDescription_0" style="display: none">
# <span class="Normal" id="dnn_ctr3867_Links_lstLinks_lbldescrdiv_0"></span>
# </div>
# </li>
# <li class="linkitem" style="white-space: nowrap">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=q3Ixvq1bWTE%3d&amp;tabid=851&amp;portalid=11&amp;mid=3867" id="dnn_ctr3867_Links_lstLinks_linkHyp_1" target="_blank">
#                     Q3 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3867_Links_lstLinks_pnlDescription_1" style="display: none">
# <span class="Normal" id="dnn_ctr3867_Links_lstLinks_lbldescrdiv_1"></span>
# </div>
# </li>
# <li class="linkitem" style="white-space: nowrap">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=yrAeGf-7jRc%3d&amp;tabid=851&amp;portalid=11&amp;mid=3867" id="dnn_ctr3867_Links_lstLinks_linkHyp_2" target="_blank">
#                     Q2 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3867_Links_lstLinks_pnlDescription_2" style="display: none">
# <span class="Normal" id="dnn_ctr3867_Links_lstLinks_lbldescrdiv_2"></span>
# </div>
# </li>
# <li class="linkitem" style="white-space: nowrap">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=JkMGilSy5Is%3d&amp;tabid=851&amp;portalid=11&amp;mid=3867" id="dnn_ctr3867_Links_lstLinks_linkHyp_3" target="_blank">
#                     Q1 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3867_Links_lstLinks_pnlDescription_3" style="display: none">
# <span class="Normal" id="dnn_ctr3867_Links_lstLinks_lbldescrdiv_3"></span>
# </div>
# </li>
# <div style="clear: both;"></div>
# </ul>
# </div>
# </div><!-- End_Module_3867 --></div>
# </div>
# <div class="c_footer">
# <div class="c_footer_l">
# </div>
# <div class="c_footer_r">
# </div>
# <div class="clear_float"></div>
# </div>
# </div>
# <div class="LimeGreen05_footer"></div></div><div class="DnnModule DnnModule-DNN_Links DnnModule-3653"><a name="3653"></a>
# <div class="LimeGreen05_style">
# <div class="LimeGreen05_top_bg">
# <div class="c_icon LimeGreen05_top_height">
# </div>
# <div class="c_title LimeGreen05_top_height">
# <h2 class="c_titles"><span class="c_title_white" id="dnn_ctr3653_dnnTITLE_titleLabel">2018 Alternative Asset Status &amp; Performance Report</span>
# </h2>
# </div>
# <div class="LimeGreen05_c_menu">
# </div>
# <div class="LimeGreen05_c_help">
# </div>
# <div class="clear_float"></div>
# </div>
# <div class="c_content_style">
# <div class="LimeGreen05_content" id="dnn_ctr3653_ContentPane"><!-- Start_Module_3653 --><div class="DNNModuleContent ModDNNLinksC" id="dnn_ctr3653_ModuleContent">
# <div class="link_module" id="dnn_ctr3653_Links_pnlList">
# <ul class="linklist">
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=AMCoPm9LzuY%3d&amp;tabid=851&amp;portalid=11&amp;mid=3653" id="dnn_ctr3653_Links_lstLinks_linkHyp_0" target="_blank">
#                     Q4 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3653_Links_lstLinks_pnlDescription_0" style="display: none">
# <span class="Normal" id="dnn_ctr3653_Links_lstLinks_lbldescrdiv_0"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=If5mvTvOO8I%3d&amp;tabid=851&amp;portalid=11&amp;mid=3653" id="dnn_ctr3653_Links_lstLinks_linkHyp_1" target="_blank">
#                     Q3 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3653_Links_lstLinks_pnlDescription_1" style="display: none">
# <span class="Normal" id="dnn_ctr3653_Links_lstLinks_lbldescrdiv_1"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=tYhTT-gLVsk%3d&amp;tabid=851&amp;portalid=11&amp;mid=3653" id="dnn_ctr3653_Links_lstLinks_linkHyp_2" target="_blank">
#                     Q2 Alternative Asset Status &amp; Performance Report - revised
#                 </a>
# <div class="item_desc" id="dnn_ctr3653_Links_lstLinks_pnlDescription_2" style="display: none">
# <span class="Normal" id="dnn_ctr3653_Links_lstLinks_lbldescrdiv_2"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=nrM620-59JE%3d&amp;tabid=851&amp;portalid=11&amp;mid=3653" id="dnn_ctr3653_Links_lstLinks_linkHyp_3" target="_blank">
#                     Q1 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3653_Links_lstLinks_pnlDescription_3" style="display: none">
# <span class="Normal" id="dnn_ctr3653_Links_lstLinks_lbldescrdiv_3"></span>
# </div>
# </li>
# <div style="clear: both;"></div>
# </ul>
# </div>
# </div><!-- End_Module_3653 --></div>
# </div>
# <div class="c_footer">
# <div class="c_footer_l">
# </div>
# <div class="c_footer_r">
# </div>
# <div class="clear_float"></div>
# </div>
# </div>
# <div class="LimeGreen05_footer"></div></div><div class="DnnModule DnnModule-DNN_Links DnnModule-3517"><a name="3517"></a>
# <div class="LimeGreen05_style">
# <div class="LimeGreen05_top_bg">
# <div class="c_icon LimeGreen05_top_height">
# </div>
# <div class="c_title LimeGreen05_top_height">
# <h2 class="c_titles"><span class="c_title_white" id="dnn_ctr3517_dnnTITLE_titleLabel">2017 Alternative Asset Status &amp; Performance Report</span>
# </h2>
# </div>
# <div class="LimeGreen05_c_menu">
# </div>
# <div class="LimeGreen05_c_help">
# </div>
# <div class="clear_float"></div>
# </div>
# <div class="c_content_style">
# <div class="LimeGreen05_content" id="dnn_ctr3517_ContentPane"><!-- Start_Module_3517 --><div class="DNNModuleContent ModDNNLinksC" id="dnn_ctr3517_ModuleContent">
# <div class="link_module" id="dnn_ctr3517_Links_pnlList">
# <ul class="linklist">
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=44ZD3XP5fxs%3d&amp;tabid=851&amp;portalid=11&amp;mid=3517" id="dnn_ctr3517_Links_lstLinks_linkHyp_0" target="_blank">
#                     Q4 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3517_Links_lstLinks_pnlDescription_0" style="display: none">
# <span class="Normal" id="dnn_ctr3517_Links_lstLinks_lbldescrdiv_0"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=EDPfqSAuERA%3d&amp;tabid=851&amp;portalid=11&amp;mid=3517" id="dnn_ctr3517_Links_lstLinks_linkHyp_1" target="_blank">
#                     Q3 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3517_Links_lstLinks_pnlDescription_1" style="display: none">
# <span class="Normal" id="dnn_ctr3517_Links_lstLinks_lbldescrdiv_1"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=ZZERcaf2-Eg%3d&amp;tabid=851&amp;portalid=11&amp;mid=3517" id="dnn_ctr3517_Links_lstLinks_linkHyp_2" target="_blank">
#                     Q2 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3517_Links_lstLinks_pnlDescription_2" style="display: none">
# <span class="Normal" id="dnn_ctr3517_Links_lstLinks_lbldescrdiv_2"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=HXbpKI6LwJs%3d&amp;tabid=851&amp;portalid=11&amp;mid=3517" id="dnn_ctr3517_Links_lstLinks_linkHyp_3" target="_blank">
#                     Q1 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3517_Links_lstLinks_pnlDescription_3" style="display: none">
# <span class="Normal" id="dnn_ctr3517_Links_lstLinks_lbldescrdiv_3"></span>
# </div>
# </li>
# <div style="clear: both;"></div>
# </ul>
# </div>
# </div><!-- End_Module_3517 --></div>
# </div>
# <div class="c_footer">
# <div class="c_footer_l">
# </div>
# <div class="c_footer_r">
# </div>
# <div class="clear_float"></div>
# </div>
# </div>
# <div class="LimeGreen05_footer"></div></div><div class="DnnModule DnnModule-DNN_Links DnnModule-3221"><a name="3221"></a>
# <div class="LimeGreen05_style">
# <div class="LimeGreen05_top_bg">
# <div class="c_icon LimeGreen05_top_height">
# </div>
# <div class="c_title LimeGreen05_top_height">
# <h2 class="c_titles"><span class="c_title_white" id="dnn_ctr3221_dnnTITLE_titleLabel">2016 Alternative Asset Status &amp; Performance Report</span>
# </h2>
# </div>
# <div class="LimeGreen05_c_menu">
# </div>
# <div class="LimeGreen05_c_help">
# </div>
# <div class="clear_float"></div>
# </div>
# <div class="c_content_style">
# <div class="LimeGreen05_content" id="dnn_ctr3221_ContentPane"><!-- Start_Module_3221 --><div class="DNNModuleContent ModDNNLinksC" id="dnn_ctr3221_ModuleContent">
# <div class="link_module" id="dnn_ctr3221_Links_pnlList">
# <ul class="linklist">
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=TKrOhBycb2c%3d&amp;tabid=851&amp;portalid=11&amp;mid=3221" id="dnn_ctr3221_Links_lstLinks_linkHyp_0" target="_blank">
#                     Q4 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3221_Links_lstLinks_pnlDescription_0" style="display: none">
# <span class="Normal" id="dnn_ctr3221_Links_lstLinks_lbldescrdiv_0"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=8zP0PZwDRDk%3d&amp;tabid=851&amp;portalid=11&amp;mid=3221" id="dnn_ctr3221_Links_lstLinks_linkHyp_1" target="_blank">
#                     Q3 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3221_Links_lstLinks_pnlDescription_1" style="display: none">
# <span class="Normal" id="dnn_ctr3221_Links_lstLinks_lbldescrdiv_1"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=SnMvCYT-PQ8%3d&amp;tabid=851&amp;portalid=11&amp;mid=3221" id="dnn_ctr3221_Links_lstLinks_linkHyp_2" target="_blank">
#                     Q2 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3221_Links_lstLinks_pnlDescription_2" style="display: none">
# <span class="Normal" id="dnn_ctr3221_Links_lstLinks_lbldescrdiv_2"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=9_L7Thqf65A%3d&amp;tabid=851&amp;portalid=11&amp;mid=3221" id="dnn_ctr3221_Links_lstLinks_linkHyp_3" target="_blank">
#                     Q1 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr3221_Links_lstLinks_pnlDescription_3" style="display: none">
# <span class="Normal" id="dnn_ctr3221_Links_lstLinks_lbldescrdiv_3"></span>
# </div>
# </li>
# <div style="clear: both;"></div>
# </ul>
# </div>
# </div><!-- End_Module_3221 --></div>
# </div>
# <div class="c_footer">
# <div class="c_footer_l">
# </div>
# <div class="c_footer_r">
# </div>
# <div class="clear_float"></div>
# </div>
# </div>
# <div class="LimeGreen05_footer"></div></div><div class="DnnModule DnnModule-DNN_Links DnnModule-2998"><a name="2998"></a>
# <div class="LimeGreen05_style">
# <div class="LimeGreen05_top_bg">
# <div class="c_icon LimeGreen05_top_height">
# </div>
# <div class="c_title LimeGreen05_top_height">
# <h2 class="c_titles"><span class="c_title_white" id="dnn_ctr2998_dnnTITLE_titleLabel">2015 Alternative Asset Status &amp; Performance Report </span>
# </h2>
# </div>
# <div class="LimeGreen05_c_menu">
# </div>
# <div class="LimeGreen05_c_help">
# </div>
# <div class="clear_float"></div>
# </div>
# <div class="c_content_style">
# <div class="LimeGreen05_content" id="dnn_ctr2998_ContentPane"><!-- Start_Module_2998 --><div class="DNNModuleContent ModDNNLinksC" id="dnn_ctr2998_ModuleContent">
# <div class="link_module" id="dnn_ctr2998_Links_pnlList">
# <ul class="linklist">
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=2s8Wz-wqWO4%3d&amp;tabid=851&amp;portalid=11&amp;mid=2998" id="dnn_ctr2998_Links_lstLinks_linkHyp_0" target="_blank">
#                     Q4 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr2998_Links_lstLinks_pnlDescription_0" style="display: none">
# <span class="Normal" id="dnn_ctr2998_Links_lstLinks_lbldescrdiv_0"></span>
# </div>
# </li>
# <li class="linkitem">
# <a alt="" class="Normal&lt;%#PopupTrigger%&gt;" href="/fsb/LinkClick.aspx?fileticket=t-aqQrB9CJU%3d&amp;tabid=851&amp;portalid=11&amp;mid=2998" id="dnn_ctr2998_Links_lstLinks_linkHyp_1" target="_blank">
#                     Q3 Alternative Asset Status &amp; Performance Report
#                 </a>
# <div class="item_desc" id="dnn_ctr2998_Links_lstLinks_pnlDescription_1" style="display: none">
# <span class="Normal" id="dnn_ctr2998_Links_lstLinks_lbldescrdiv_1"></span>
# </div>
# </li>
# <div style="clear: both;"></div>
# </ul>
# </div>
# </div><!-- End_Module_2998 --></div>
# </div>
# <div class="c_footer">
# <div class="c_footer_l">
# </div>
# <div class="c_footer_r">
# </div>
# <div class="clear_float"></div>
# </div>
# </div>
# <div class="LimeGreen05_footer"></div></div></div>
# </div>
# <div class="row-fluid dnnpane">
# <div class="one_grid8 span8 DNNEmptyPane" id="dnn_OneGrid8"></div>
# <div class="one_grid4 span4 DNNEmptyPane" id="dnn_OneGrid4"></div>
# </div>
# <div class="row-fluid dnnpane">
# <div class="two_grid6a span6 DNNEmptyPane" id="dnn_TwoGrid6A"></div>
# <div class="two_grid6b span6 DNNEmptyPane" id="dnn_TwoGrid6B"></div>
# </div>
# <div class="row-fluid dnnpane">
# <div class="three_grid4a span4 DNNEmptyPane" id="dnn_ThreeGrid4A"></div>
# <div class="three_grid4b span4 DNNEmptyPane" id="dnn_ThreeGrid4B"></div>
# <div class="three_grid4c span4 DNNEmptyPane" id="dnn_ThreeGrid4C"></div>
# </div>
# <div class="row-fluid dnnpane">
# <div class="four_grid12 span12 DNNEmptyPane" id="dnn_FourGrid12"></div>
# </div>
# <div class="row-fluid dnnpane">
# <div class="five_grid3a span3 DNNEmptyPane" id="dnn_FiveGrid3A"></div>
# <div class="five_grid3b span3 DNNEmptyPane" id="dnn_FiveGrid3B"></div>
# <div class="five_grid3c span3 DNNEmptyPane" id="dnn_FiveGrid3C"></div>
# <div class="five_grid3d span3 DNNEmptyPane" id="dnn_FiveGrid3D"></div>
# </div>
# <div class="row-fluid dnnpane">
# <div class="six_grid4 span4 DNNEmptyPane" id="dnn_SixGrid4"></div>
# <div class="six_grid8 span8 DNNEmptyPane" id="dnn_SixGrid8"></div>
# </div>
# <div class="row-fluid dnnpane">
# <div class="seven_grid12 span12 DNNEmptyPane" id="dnn_SevenGrid12"></div>
# </div>
# <div class="row-fluid dnnpane">
# <div class="eight_grid9 span9 DNNEmptyPane" id="dnn_EightGrid9"></div>
# <div class="eight_grid3 span3 DNNEmptyPane" id="dnn_EightGrid3"></div>
# </div>
# </section>
# <!--end main content area-->
# </div>
# <div class="skin_bottom_line"></div>
# <!--start skin footer-->
# <footer id="skin_footer">
# <!--start footer top content-->
# <div class="footer_top">
# <div class="skin_width">
# <div class="footerpane_style">
# <div class="row-fluid dnnpane">
# <div class="footer_grid3a span3 DNNEmptyPane" id="dnn_FooterGrid3A"></div>
# <div class="footer_grid3b span3 DNNEmptyPane" id="dnn_FooterGrid3B"></div>
# <div class="footer_grid3c span3 DNNEmptyPane" id="dnn_FooterGrid3C"></div>
# <div class="footer_grid3d span3 DNNEmptyPane" id="dnn_FooterGrid3D"></div>
# </div>
# <div class="row-fluid dnnpane">
# <div class="footerpane span12" id="dnn_FooterPane"><div class="DnnModule DnnModule-DNN_HTML DnnModule-2697 DnnVersionableControl"><a name="2697"></a><div id="dnn_ctr2697_ContentPane"><!-- Start_Module_2697 --><div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr2697_ModuleContent">
# <div id="dnn_ctr2697_HtmlModule_lblContent"><div style="text-align: center;">
# <div>State Board of Administration of Florida</div>
# <div>1801 Hermitage Blvd. Suite 100, Tallahassee, Florida 32308</div>
# <div>P.O. Box 13300 Tallahassee, Florida 32317-3300</div>
# <div>Phone (850) 488-4406</div>
# </div></div>
# </div><!-- End_Module_2697 --></div>
# </div></div>
# </div>
# </div>
# </div>
# </div>
# <!--end footer top content-->
# <!--start copyrightbar-->
# <div class="footer_bottom">
# <div class="skin_width clearafter">
# <div class="copyright_style">
# <span class="Footer" id="dnn_dnnCOPYRIGHT_lblCopyright">Copyright 2023 by Florida State Board of Administration</span>
#
#           |
#           <a class="Footer" href="https://www.sbafla.com/fsb/privacy.aspx" id="dnn_dnnPRIVACY_hypPrivacy" rel="nofollow">Privacy Statement</a>
#           |
#           <a class="Footer" href="https://www.sbafla.com/fsb/terms.aspx" id="dnn_dnnTERMS_hypTerms" rel="nofollow">Terms Of Use</a>
# 		  |
#
#             <a class="Footer" href="https://www.sbafla.com/fsb/LoginS/tabid/707/Default.aspx">Login</a>
# </div>
# <div class="socialp_style">
# <div class="DNNEmptyPane" id="dnn_SocialMediaPane"></div>
# </div>
# </div>
# </div>
# <!--end copyrightbar-->
# </footer>
# <!--end skin footer-->
# <a href="#top" id="top-link" title=""></a> </div>
# <script src="/Resources/Shared/Scripts/jquery/jquery.hoverIntent.min.js" type="text/javascript"></script>
# <script src="/Resources/Libraries/jQuery-UI/01_11_03/jquery-ui.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/StandardMenu/StandardMenu.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/MegaMenu/MegaMenu.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/trans-banner.min.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/jquery.scrollTo.min.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/scrolltop.call.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/jquery.fancybox.min.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/jquery.mousewheel.min.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/animatedcollapse.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/jquery.easing.1.3.min.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/jquery.tipsy.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/bootstrap/js/bootstrap.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/jquery.accordion.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/jquery.carouFredSel-6.2.1-packed.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/jquery.quovolver.min.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/jquery.isotope.min.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/jquery.inview.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/jquery.retinise.min.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/shake.js" type="text/javascript"></script>
# <script src="/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/js/custom.js" type="text/javascript"></script>
# <input id="ScrollTop" name="ScrollTop" type="hidden"/>
# <input autocomplete="off" id="__dnnVariable" name="__dnnVariable" type="hidden" value="`{`__scdoff`:`1`,`sf_siteRoot`:`/fsb/`,`sf_tabId`:`851`,`evoq_TabId`:`851`,`evoq_PageLanguage`:`en-US`,`evoq_ContentItemId`:`-1`,`evoq_UrlReferrer`:``,`evoq_UrlPath`:`https%3a%2f%2fwww.sbafla.com%2ffsb%2fPerformanceReports%2fAlternativeAssetStatusPerformanceReport.aspx`,`evoq_UrlQuery`:`%3fTabID%3d851`,`evoq_ContentItemReferrer`:`-1`,`evoq_PersonalizedUrlReferrer`:`-1`,`evoq_DisableAnalytics`:`False`}"/>
# <input name="__RequestVerificationToken" type="hidden" value="FSJWg39rOcwHV6LdU9Bsm6-nENifs3ShwkSLCMunVwy2rHcc7JuE5-atQ49_7xLq3j7XHg2"/>
# <script type="text/javascript">
# //<![CDATA[
# (function() {
#
#   var analyticsSettings;
#   var initAnalyticsSettings = function (e) {
#     analyticsSettings = {
#       pageStart: analytics_page_startTime,
#       servicesFramework: $.ServicesFramework(-1)
#     };
#   };
#   if(window.addEventListener) {
#     window.addEventListener('load', initAnalyticsSettings, false);
#   } else {
#     window.attachEvent('onload', initAnalyticsSettings);
#   };
#
#   var eventName = (window.onpagehide || window.onpagehide === null) ? 'pagehide' : 'unload';
#   if (window.addEventListener) {
#     window.addEventListener(eventName, function (e) {
#       if (analyticsSettings) {
#         analyticsSettings.eventSource = 'pagehide';
#         if(dnn && dnn.analytics) { dnn.analytics.clientUnloading(e,analyticsSettings); }
#       }
#     }, false);
#   } else {
#     window.attachEvent('on' + eventName, function (e) {
#       if (analyticsSettings) {
#         analyticsSettings.eventSource = 'pagehide';
#         if(dnn && dnn.analytics) { dnn.analytics.clientUnloading(e,analyticsSettings); }
#       }
#     });
#   }
#
# })();
# //]]>
# </script>
# </form>
# <!--CDF(Javascript|/fsb/js/dnncore.js?cdv=223)--><!--CDF(Css|/fsb/Resources/Shared/stylesheets/dnndefault/7.0.0/default.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Skins/CleanWeb-LimeGreen/skin.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/container.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/Container05.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/container.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/Container05.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/container.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/Container05.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/container.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/Container05.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/container.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/Container05.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/container.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/Container05.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/container.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/Container05.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/container.css?cdv=223)--><!--CDF(Css|/fsb/Portals/_default/Containers/CleanWeb-LimeGreen/Container05.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/DesktopModules/Links/module.css?cdv=223)--><!--CDF(Css|/fsb/Portals/FSB/portal.css?cdv=223)--><!--CDF(Css|/fsb/Resources/Search/SearchSkinObjectPreview.css?cdv=223)--><!--CDF(Javascript|/fsb/Resources/Search/SearchSkinObjectPreview.js?cdv=223)--><!--CDF(Css|/fsb/Resources/Search/SearchSkinObjectPreview.css?cdv=223)--><!--CDF(Javascript|/fsb/Resources/Search/SearchSkinObjectPreview.js?cdv=223)--><!--CDF(Javascript|/fsb/DesktopModules/DNNCorp/EvoqContentLibrary/ClientScripts/dnn.analytics.Injected.js?cdv=223)--><!--CDF(Javascript|/fsb/js/dnn.js?cdv=223)--><!--CDF(Javascript|/fsb/js/dnn.servicesframework.js?cdv=223)--><!--CDF(Javascript|/fsb/Resources/libraries/jQuery/01_09_01/jquery.js?cdv=223)-->
# </body>
# </html>

# %%
def parse_page(url):
    """
    Parse all the PDF urls from the provided URL's HTML.
    """
    r = requests.get(url)
    soup = BeautifulSoup(r.text)
    return soup
    a_list = soup.find_all("a")
    pdf_list = [a['href'] for a in a_list if a['href'].endswith(".pdf")]
    return [f"http://hsr.ca.gov{href}" for href in pdf_list]

# %%
page_list=['https://www.sbafla.com/fsb/PerformanceReports/AlternativeAssetStatusPerformanceReport.aspx']

# %%
pdf_list = []

# %%
for page in page_list:
    pdfs = parse_page(page)
    print(pdfs)
    #pdf_list.extend(pdfs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# notebook.ipynb Cell 13 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/notebook.ipynb?repo%3Dmconsulting%2Fhsr-document-analysis#X14scmVwbw%3D%3D?line=0'>1</a> for page in page_list:
# ----> <a href='vscode-notebook-cell:/notebook.ipynb?repo%3Dmconsulting%2Fhsr-document-analysis#X14scmVwbw%3D%3D?line=1'>2</a>     pdfs = parse_page(page)
#       <a href='vscode-notebook-cell:/notebook.ipynb?repo%3Dmconsulting%2Fhsr-document-analysis#X14scmVwbw%3D%3D?line=2'>3</a>     print(pdfs)
#
# notebook.ipynb Cell 13 in parse_page(url)
#       <a href='vscode-notebook-cell:/notebook.ipynb?repo%3Dmconsulting%2Fhsr-document-analysis#X14scmVwbw%3D%3D?line=5'>6</a> soup = BeautifulSoup(r.text)
#       <a href='vscode-notebook-cell:/notebook.ipynb?repo%3Dmconsulting%2Fhsr-document-analysis#X14scmVwbw%3D%3D?line=6'>7</a> a_list = soup.find_all("a")
# ----> <a href='vscode-notebook-cell:/notebook.ipynb?repo%3Dmconsulting%2Fhsr-document-analysis#X14scmVwbw%3D%3D?line=7'>8</a> pdf_list = [a['href'] for a in a_list if a['href'].endswith(".pdf")]
#       <a href='vscode-notebook-cell:/notebook.ipynb?repo%3Dmconsulting%2Fhsr-document-analysis#X14scmVwbw%3D%3D?line=8'>9</a> return [f"http://hsr.ca.gov{href}" for href in pdf_list]
#
# notebook.ipynb Cell 13 in <listcomp>(.0)
#       <a href='vscode-notebook-cell:/notebook.ipynb?repo%3Dmconsulting%2Fhsr-document-analysis#X14scmVwbw%3D%3D?line=5'>6</a> soup = BeautifulSoup(r.text)
#       <a href='vscode-notebook-cell:/notebook.ipynb?repo%3Dmconsulting%2Fhsr-document-analysis#X14scmVwbw%3D%3D?line=6'>7</a> a_list = soup.find_all("a")
# ----> <a href='vscode-notebook-cell:/notebook.ipynb?repo%3Dmconsulting%2Fhsr-document-analysis#X14scmVwbw%3D%3D?line=7'>8</a> pdf_list = [a['href'] for a in a_list if a['href'].endswith(".pdf")]
#       <a href='vscode-notebook-cell:/notebook.ipynb?repo%3Dmconsulting%2Fhsr-document-analysis#X14scmVwbw%3D%3D?line=8'>9</a> return [f"http://hsr.ca.gov{href}" for href in pdf_list]
#
# File c:\Users\mason_000\anaconda3\lib\site-packages\bs4\element.py:1519, in Tag.__getitem__(self, key)
#    1516 def __getitem__(self, key):
#    1517     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1518     and throws an exception if it's not there."""
# -> 1519     return self.attrs[key]
#
# KeyError: 'href'

# %% [markdown]
# How many total PDF urls were found?

# %%
f"{len(pdf_list):,}"
# Out:
# '3,410'

# %% [markdown]
# Remove all of the duplicates.

# %%
pdf_set = set(pdf_list)

# %% [markdown]
# How many URLs remain?

# %%
f"{len(pdf_set):,}"
# Out:
# '3,168'

# %% [markdown]
# Download them all.

# %%
def download_pdf(url):
    """
    Download a PDF url to the output folder.
    """
    filename = url.split("/")[-1]
    path = output_dir.joinpath(filename)
    if path.exists():
        return
    try:
        print(f"Downloading {filename}")
        urlretrieve(url, path)
    except Exception:
        print(f"Failed to download {url}")

# %%
for url in pdf_set:
    download_pdf(url)

# %% [markdown]
# Get their page counts.

# %%
def get_page_count(path):
    """
    Get the page count of the provided PDF path.
    """
    with open(path, 'rb') as f:
        try:
            pdfReader = PyPDF2.PdfFileReader(f)
            return pdfReader.numPages
        except:
            return pd.np.NaN

# %%
path_list = list(output_dir.glob('*.pdf'))

# %% [markdown]
# Count the total number of documents again to check out many we actually downloaded.

# %%
f"{len(pdf_path_list):,}"
# Out:
# '3,129'

# %% [markdown]
# Loop through all the documents and tally pages.

# %%
page_counts = dict((p, get_page_count(p)) for p in path_list)

# %%
df = pd.DataFrame(pdf_page_counts.items(), columns=["pdf", "page_count"])

# %%
df.sort_values("page_count", ascending=False).head()
# Out:
#                                                     pdf  page_count
# 1413  /media/palewire/Passport/hsr-pdfs/final_EIR_Me...      8923.0
# 142   /media/palewire/Passport/hsr-pdfs/final_ERIS_F...      4297.0
# 2108  /media/palewire/Passport/hsr-pdfs/BayCValley20...      2126.0
# 2508  /media/palewire/Passport/hsr-pdfs/brdmtg_04211...      1523.0
# 2421  /media/palewire/Passport/hsr-pdfs/Los_Angeles_...      1369.0

# %%
len(df)
# Out:
# 3129

# %%
f"{df.page_count.sum():,}"
# Out:
# '151,703.0'
